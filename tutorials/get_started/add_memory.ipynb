# %% [markdown]
# # Agent Memory
#
# [![Open in Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/datascienceworld-kan/vinagent/blob/main/docs/docs/tutorials/get_started/agent_memory.ipynb)

# %% [markdown]
# Vinagent features a Graphical Memory system that transforms messages into a structured knowledge graph composed of nodes, relationships, and edges. This memory can be organized into short-term and long-term components, allowing the Agent to retain and recall learned information effectively.
#
# Compared to traditional Conversational Memory, Graphical Memory offers distinct advantages: it condenses essential information into a graph format, reducing hallucinations by filtering out redundant or irrelevant details. Additionally, because it operates with a shorter context length, it significantly lowers computational costs.
#
# This graph-based approach mirrors how humans conceptualize and retain knowledge, making it especially powerful for capturing the core meaning of complex conversations.

# %% [markdown]
# ## Setup
#
# Install `vinagent` package

# %%
# %pip install -U vinagent
# Out:
# Collecting vinagent
#   Downloading vinagent-0.0.6.post3-py3-none-any.whl (147 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 147.1/147.1 kB 1.2 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: passlib==1.7.4 in /Users/phamdinhkhanh/Documents/Courses/Manus/vinagent/.venv/lib/python3.10/site-packages (from vinagent) (1.7.4)
# Requirement already satisfied: mlflow-skinny==3.1.0 in /Users/phamdinhkhanh/Documents/Courses/Manus/vinagent/.venv/lib/python3.10/site-packages (from vinagent) (3.1.0)
# Requirement already satisfied: mcp==1.9.0 in /Users/phamdinhkhanh/Documents/Courses/Manus/vinagent/.venv/lib/python3.10/site-packages (from vinagent) (1.9.0)
# Requirement already satisfied: mlflow==3.1.0 in /Users/phamdinhkhanh/Documents/Courses/Manus/vinagent/.venv/lib/python3.10/site-packages (from vinagent) (3.1.0)
# Requirement already satisfied: bcrypt==4.3.0 in /Users/phamdinhkhanh/Documents/Courses/Manus/vinagent/.venv/lib/python3.10/site-packages (from vinagent) (4.3.0)
# Collecting PyJWT==2.10.1
#   Using cached PyJWT-2.10.1-py3-none-any.whl (22 kB)
# Requirement already satisfied: aucodb[graph]==0.1.8.post3 in /Users/phamdinhkhanh/Documents/Courses/Manus/vinagent/.venv/lib/python3.10/site-packages (from vinagent) (0.1.8.post3)
# Requirement already satisfied: arxiv==2.1.3 in /Users/phamdinhkhanh/Documents/Courses/Manus/vinagent/.venv/lib/python3.10/site-packages (from vinagent) (2.1.3)
# Requirement already satisfied: langchain-together==0.3.0 in /Users/phamdinhkhanh/Documents/Courses/Manus/vinagent/.venv/lib/python3.10/site-packages (from vinagent) (0.3.0)
# Requirement already satisfied: yfinance==0.2.54 in /Users/phamdinhkhanh/Documents/Courses/Manus/vinagent/.venv/lib/python3.10/site-packages (from vinagent) (0.2.54)
# Requirement already satisfied: langchain-groq==0.3.6 in /Users/phamdinhkhanh/Documents/Courses/Manus/vinagent/.venv/lib/python3.10/site-packages (from vinagent) (0.3.6)
# Requirement already satisfied: langgraph==0.4.7 in /Users/phamdinhkhanh/Documents/Courses/Manus/vinagent/.venv/lib/python3.10/site-packages (from vinagent) (0.4.7)
# Requirement already satisfied: langchain-core==0.3.68 in /Users/phamdinhkhanh/Documents/Courses/Manus/vinagent/.venv/lib/python3.10/site-packages (from vinagent) (0.3.68)
# Requirement already satisfied: matplotlib==3.7.1 in /Users/phamdinhkhanh/Documents/Courses/Manus/vinagent/.venv/lib/python3.10/site-packages (from vinagent) (3.7.1)
# Requirement already satisfied: pandas==2.2.3 in /Users/phamdinhkhanh/Documents/Courses/Manus/vinagent/.venv/lib/python3.10/site-packages (from vinagent) (2.2.3)
# Requirement already satisfied: plotly==5.22.0 in /Users/phamdinhkhanh/Documents/Courses/Manus/vinagent/.venv/lib/python3.10/site-packages (from vinagent) (5.22.0)
# Requirement already satisfied: langchain-openai==0.3.7 in /Users/phamdinhkhanh/Documents/Courses/Manus/vinagent/.venv/lib/python3.10/site-packages (from vinagent) (0.3.7)
# Requirement already satisfied: python-dotenv==1.0.0 in /Users/phamdinhkhanh/Documents/Courses/Manus/vinagent/.venv/lib/python3.10/site-packages (from vinagent) (1.0.0)
# Requirement already satisfied: typing_extensions==4.14.1 in /Users/phamdinhkhanh/Documents/Courses/Manus/vinagent/.venv/lib/python3.10/site-packages (from vinagent) (4.14.1)
# Requirement already satisfied: googlenewsdecoder==0.1.7 in /Users/phamdinhkhanh/Documents/Courses/Manus/vinagent/.venv/lib/python3.10/site-packages (from vinagent) (0.1.7)
# Requirement already satisfied: feedparser~=6.0.10 in /Users/phamdinhkhanh/Documents/Courses/Manus/vinagent/.venv/lib/python3.10/site-packages (from arxiv==2.1.3->vinagent) (6.0.11)
# Requirement already satisfied: requests~=2.32.0 in /Users/phamdinhkhanh/Documents/Courses/Manus/vinagent/.venv/lib/python3.10/site-packages (from arxiv==2.1.3->vinagent) (2.32.3)
# Requirement already satisfied: fastapi<0.116.0,>=0.115.0 in /Users/phamdinhkhanh/Documents/Courses/Manus/vinagent/.venv/lib/python3.10/site-packages (from aucodb[graph]==0.1.8.post3->vinagent) (0.115.14)
# Requirement already satisfied: aiofiles==24.1.0 in /Users/phamdinhkhanh/Documents/Courses/Manus/vinagent/.venv/lib/python3.10/site-packages (from aucodb[graph]==0.1.8.post3->vinagent) (24.1.0)
# Requirement already satisfied: ipykernel==6.29.5 in /Users/phamdinhkhanh/Documents/Courses/Manus/vinagent/.venv/lib/python3.10/site-packages (from aucodb[graph]==0.1.8.post3->vinagent) (6.29.5)
# Requirement already satisfied: uvicorn>=0.22.0 in /Users/phamdinhkhanh/Documents/Courses/Manus/vinagent/.venv/lib/python3.10/site-packages (from aucodb[graph]==0.1.8.post3->vinagent) (0.35.0)
# Requirement already satisfied: pydantic<3.0,>=2.0 in /Users/phamdinhkhanh/Documents/Courses/Manus/vinagent/.venv/lib/python3.10/site-packages (from aucodb[graph]==0.1.8.post3->vinagent) (2.11.7)
# Requirement already satisfied: pyvis==0.3.2 in /Users/phamdinhkhanh/Documents/Courses/Manus/vinagent/.venv/lib/python3.10/site-packages (from aucodb[graph]==0.1.8.post3->vinagent) (0.3.2)
# Requirement already satisfied: neo4j==5.28.1 in /Users/phamdinhkhanh/Documents/Courses/Manus/vinagent/.venv/lib/python3.10/site-packages (from aucodb[graph]==0.1.8.post3->vinagent) (5.28.1)
# Requirement already satisfied: pysocks>=1.7.1 in /Users/phamdinhkhanh/Documents/Courses/Manus/vinagent/.venv/lib/python3.10/site-packages (from googlenewsdecoder==0.1.7->vinagent) (1.7.1)
# Requirement already satisfied: selectolax>=0.3.27 in /Users/phamdinhkhanh/Documents/Courses/Manus/vinagent/.venv/lib/python3.10/site-packages (from googlenewsdecoder==0.1.7->vinagent) (0.3.32)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /Users/phamdinhkhanh/Documents/Courses/Manus/vinagent/.venv/lib/python3.10/site-packages (from langchain-core==0.3.68->vinagent) (1.33)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /Users/phamdinhkhanh/Documents/Courses/Manus/vinagent/.venv/lib/python3.10/site-packages (from langchain-core==0.3.68->vinagent) (9.1.2)
# Requirement already satisfied: langsmith>=0.3.45 in /Users/phamdinhkhanh/Documents/Courses/Manus/vinagent/.venv/lib/python3.10/site-packages (from langchain-core==0.3.68->vinagent) (0.3.45)
# Requirement already satisfied: packaging<25,>=23.2 in /Users/phamdinhkhanh/Documents/Courses/Manus/vinagent/.venv/lib/python3.10/site-packages (from langchain-core==0.3.68->vinagent) (24.2)
# Requirement already satisfied: PyYAML>=5.3 in /Users/phamdinhkhanh/Documents/Courses/Manus/vinagent/.venv/lib/python3.10/site-packages (from langchain-core==0.3.68->vinagent) (6.0.2)
# Requirement already satisfied: groq<1,>=0.29.0 in /Users/phamdinhkhanh/Documents/Courses/Manus/vinagent/.venv/lib/python3.10/site-packages (from langchain-groq==0.3.6->vinagent) (0.30.0)
# Requirement already satisfied: tiktoken<1,>=0.7 in /Users/phamdinhkhanh/Documents/Courses/Manus/vinagent/.venv/lib/python3.10/site-packages (from langchain-openai==0.3.7->vinagent) (0.9.0)
# Requirement already satisfied: openai<2.0.0,>=1.58.1 in /Users/phamdinhkhanh/Documents/Courses/Manus/vinagent/.venv/lib/python3.10/site-packages (from langchain-openai==0.3.7->vinagent) (1.97.0)
# Requirement already satisfied: aiohttp<4.0.0,>=3.9.1 in /Users/phamdinhkhanh/Documents/Courses/Manus/vinagent/.venv/lib/python3.10/site-packages (from langchain-together==0.3.0->vinagent) (3.12.14)
# Requirement already satisfied: xxhash>=3.5.0 in /Users/phamdinhkhanh/Documents/Courses/Manus/vinagent/.venv/lib/python3.10/site-packages (from langgraph==0.4.7->vinagent) (3.5.0)
# Requirement already satisfied: langgraph-checkpoint>=2.0.26 in /Users/phamdinhkhanh/Documents/Courses/Manus/vinagent/.venv/lib/python3.10/site-packages (from langgraph==0.4.7->vinagent) (2.1.1)
# Requirement already satisfied: langgraph-prebuilt>=0.2.0 in /Users/phamdinhkhanh/Documents/Courses/Manus/vinagent/.venv/lib/python3.10/site-packages (from langgraph==0.4.7->vinagent) (0.6.4)
# Requirement already satisfied: langgraph-sdk>=0.1.42 in /Users/phamdinhkhanh/Documents/Courses/Manus/vinagent/.venv/lib/python3.10/site-packages (from langgraph==0.4.7->vinagent) (0.2.0)
# Requirement already satisfied: pillow>=6.2.0 in /Users/phamdinhkhanh/Documents/Courses/Manus/vinagent/.venv/lib/python3.10/site-packages (from matplotlib==3.7.1->vinagent) (11.3.0)
# Requirement already satisfied: cycler>=0.10 in /Users/phamdinhkhanh/Documents/Courses/Manus/vinagent/.venv/lib/python3.10/site-packages (from matplotlib==3.7.1->vinagent) (0.12.1)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/phamdinhkhanh/Documents/Courses/Manus/vinagent/.venv/lib/python3.10/site-packages (from matplotlib==3.7.1->vinagent) (2.9.0.post0)
# Requirement already satisfied: numpy>=1.20 in /Users/phamdinhkhanh/Documents/Courses/Manus/vinagent/.venv/lib/python3.10/site-packages (from matplotlib==3.7.1->vinagent) (2.2.6)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/phamdinhkhanh/Documents/Courses/Manus/vinagent/.venv/lib/python3.10/site-packages (from matplotlib==3.7.1->vinagent) (3.2.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/phamdinhkhanh/Documents/Courses/Manus/vinagent/.venv/lib/python3.10/site-packages (from matplotlib==3.7.1->vinagent) (1.4.8)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/phamdinhkhanh/Documents/Courses/Manus/vinagent/.venv/lib/python3.10/site-packages (from matplotlib==3.7.1->vinagent) (1.3.2)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/phamdinhkhanh/Documents/Courses/Manus/vinagent/.venv/lib/python3.10/site-packages (from matplotlib==3.7.1->vinagent) (4.59.0)
# Requirement already satisfied: python-multipart>=0.0.9 in /Users/phamdinhkhanh/Documents/Courses/Manus/vinagent/.venv/lib/python3.10/site-packages (from mcp==1.9.0->vinagent) (0.0.20)
# Requirement already satisfied: starlette>=0.27 in /Users/phamdinhkhanh/Documents/Courses/Manus/vinagent/.venv/lib/python3.10/site-packages (from mcp==1.9.0->vinagent) (0.46.2)
# Requirement already satisfied: anyio>=4.5 in /Users/phamdinhkhanh/Documents/Courses/Manus/vinagent/.venv/lib/python3.10/site-packages (from mcp==1.9.0->vinagent) (4.9.0)
# Requirement already satisfied: httpx-sse>=0.4 in /Users/phamdinhkhanh/Documents/Courses/Manus/vinagent/.venv/lib/python3.10/site-packages (from mcp==1.9.0->vinagent) (0.4.1)
# Requirement already satisfied: sse-starlette>=1.6.1 in /Users/phamdinhkhanh/Documents/Courses/Manus/vinagent/.venv/lib/python3.10/site-packages (from mcp==1.9.0->vinagent) (2.4.1)
# Requirement already satisfied: pydantic-settings>=2.5.2 in /Users/phamdinhkhanh/Documents/Courses/Manus/vinagent/.venv/lib/python3.10/site-packages (from mcp==1.9.0->vinagent) (2.10.1)
# Requirement already satisfied: httpx>=0.27 in /Users/phamdinhkhanh/Documents/Courses/Manus/vinagent/.venv/lib/python3.10/site-packages (from mcp==1.9.0->vinagent) (0.28.1)
# Requirement already satisfied: sqlalchemy<3,>=1.4.0 in /Users/phamdinhkhanh/Documents/Courses/Manus/vinagent/.venv/lib/python3.10/site-packages (from mlflow==3.1.0->vinagent) (2.0.41)
# Requirement already satisfied: docker<8,>=4.0.0 in /Users/phamdinhkhanh/Documents/Courses/Manus/vinagent/.venv/lib/python3.10/site-packages (from mlflow==3.1.0->vinagent) (7.1.0)
# Requirement already satisfied: alembic!=1.10.0,<2 in /Users/phamdinhkhanh/Documents/Courses/Manus/vinagent/.venv/lib/python3.10/site-packages (from mlflow==3.1.0->vinagent) (1.16.4)
# Requirement already satisfied: scikit-learn<2 in /Users/phamdinhkhanh/Documents/Courses/Manus/vinagent/.venv/lib/python3.10/site-packages (from mlflow==3.1.0->vinagent) (1.7.1)
# Requirement already satisfied: pyarrow<21,>=4.0.0 in /Users/phamdinhkhanh/Documents/Courses/Manus/vinagent/.venv/lib/python3.10/site-packages (from mlflow==3.1.0->vinagent) (20.0.0)
# Requirement already satisfied: scipy<2 in /Users/phamdinhkhanh/Documents/Courses/Manus/vinagent/.venv/lib/python3.10/site-packages (from mlflow==3.1.0->vinagent) (1.15.3)
# Requirement already satisfied: graphene<4 in /Users/phamdinhkhanh/Documents/Courses/Manus/vinagent/.venv/lib/python3.10/site-packages (from mlflow==3.1.0->vinagent) (3.4.3)
# Requirement already satisfied: gunicorn<24 in /Users/phamdinhkhanh/Documents/Courses/Manus/vinagent/.venv/lib/python3.10/site-packages (from mlflow==3.1.0->vinagent) (23.0.0)
# Requirement already satisfied: Flask<4 in /Users/phamdinhkhanh/Documents/Courses/Manus/vinagent/.venv/lib/python3.10/site-packages (from mlflow==3.1.0->vinagent) (3.1.1)
# Requirement already satisfied: databricks-sdk<1,>=0.20.0 in /Users/phamdinhkhanh/Documents/Courses/Manus/vinagent/.venv/lib/python3.10/site-packages (from mlflow-skinny==3.1.0->vinagent) (0.59.0)
# Requirement already satisfied: sqlparse<1,>=0.4.0 in /Users/phamdinhkhanh/Documents/Courses/Manus/vinagent/.venv/lib/python3.10/site-packages (from mlflow-skinny==3.1.0->vinagent) (0.5.3)
# Requirement already satisfied: click<9,>=7.0 in /Users/phamdinhkhanh/Documents/Courses/Manus/vinagent/.venv/lib/python3.10/site-packages (from mlflow-skinny==3.1.0->vinagent) (8.2.1)
# Requirement already satisfied: opentelemetry-api<3,>=1.9.0 in /Users/phamdinhkhanh/Documents/Courses/Manus/vinagent/.venv/lib/python3.10/site-packages (from mlflow-skinny==3.1.0->vinagent) (1.35.0)
# Requirement already satisfied: cloudpickle<4 in /Users/phamdinhkhanh/Documents/Courses/Manus/vinagent/.venv/lib/python3.10/site-packages (from mlflow-skinny==3.1.0->vinagent) (3.1.1)
# Requirement already satisfied: opentelemetry-sdk<3,>=1.9.0 in /Users/phamdinhkhanh/Documents/Courses/Manus/vinagent/.venv/lib/python3.10/site-packages (from mlflow-skinny==3.1.0->vinagent) (1.35.0)
# Requirement already satisfied: gitpython<4,>=3.1.9 in /Users/phamdinhkhanh/Documents/Courses/Manus/vinagent/.venv/lib/python3.10/site-packages (from mlflow-skinny==3.1.0->vinagent) (3.1.44)
# Requirement already satisfied: cachetools<7,>=5.0.0 in /Users/phamdinhkhanh/Documents/Courses/Manus/vinagent/.venv/lib/python3.10/site-packages (from mlflow-skinny==3.1.0->vinagent) (5.5.2)
# Requirement already satisfied: importlib_metadata!=4.7.0,<9,>=3.7.0 in /Users/phamdinhkhanh/Documents/Courses/Manus/vinagent/.venv/lib/python3.10/site-packages (from mlflow-skinny==3.1.0->vinagent) (8.7.0)
# Requirement already satisfied: protobuf<7,>=3.12.0 in /Users/phamdinhkhanh/Documents/Courses/Manus/vinagent/.venv/lib/python3.10/site-packages (from mlflow-skinny==3.1.0->vinagent) (6.31.1)
# Requirement already satisfied: pytz>=2020.1 in /Users/phamdinhkhanh/Documents/Courses/Manus/vinagent/.venv/lib/python3.10/site-packages (from pandas==2.2.3->vinagent) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/phamdinhkhanh/Documents/Courses/Manus/vinagent/.venv/lib/python3.10/site-packages (from pandas==2.2.3->vinagent) (2025.2)
# Requirement already satisfied: platformdirs>=2.0.0 in /Users/phamdinhkhanh/Documents/Courses/Manus/vinagent/.venv/lib/python3.10/site-packages (from yfinance==0.2.54->vinagent) (4.3.8)
# Requirement already satisfied: peewee>=3.16.2 in /Users/phamdinhkhanh/Documents/Courses/Manus/vinagent/.venv/lib/python3.10/site-packages (from yfinance==0.2.54->vinagent) (3.18.2)
# Requirement already satisfied: frozendict>=2.3.4 in /Users/phamdinhkhanh/Documents/Courses/Manus/vinagent/.venv/lib/python3.10/site-packages (from yfinance==0.2.54->vinagent) (2.4.6)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in /Users/phamdinhkhanh/Documents/Courses/Manus/vinagent/.venv/lib/python3.10/site-packages (from yfinance==0.2.54->vinagent) (4.13.4)
# Requirement already satisfied: multitasking>=0.0.7 in /Users/phamdinhkhanh/Documents/Courses/Manus/vinagent/.venv/lib/python3.10/site-packages (from yfinance==0.2.54->vinagent) (0.0.12)
# Requirement already satisfied: tornado>=6.1 in /Users/phamdinhkhanh/Documents/Courses/Manus/vinagent/.venv/lib/python3.10/site-packages (from ipykernel==6.29.5->aucodb[graph]==0.1.8.post3->vinagent) (6.5.1)
# Requirement already satisfied: matplotlib-inline>=0.1 in /Users/phamdinhkhanh/Documents/Courses/Manus/vinagent/.venv/lib/python3.10/site-packages (from ipykernel==6.29.5->aucodb[graph]==0.1.8.post3->vinagent) (0.1.7)
# Requirement already satisfied: appnope in /Users/phamdinhkhanh/Documents/Courses/Manus/vinagent/.venv/lib/python3.10/site-packages (from ipykernel==6.29.5->aucodb[graph]==0.1.8.post3->vinagent) (0.1.4)
# Requirement already satisfied: jupyter-client>=6.1.12 in /Users/phamdinhkhanh/Documents/Courses/Manus/vinagent/.venv/lib/python3.10/site-packages (from ipykernel==6.29.5->aucodb[graph]==0.1.8.post3->vinagent) (8.6.3)
# Requirement already satisfied: debugpy>=1.6.5 in /Users/phamdinhkhanh/Documents/Courses/Manus/vinagent/.venv/lib/python3.10/site-packages (from ipykernel==6.29.5->aucodb[graph]==0.1.8.post3->vinagent) (1.8.15)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /Users/phamdinhkhanh/Documents/Courses/Manus/vinagent/.venv/lib/python3.10/site-packages (from ipykernel==6.29.5->aucodb[graph]==0.1.8.post3->vinagent) (5.8.1)
# Requirement already satisfied: pyzmq>=24 in /Users/phamdinhkhanh/Documents/Courses/Manus/vinagent/.venv/lib/python3.10/site-packages (from ipykernel==6.29.5->aucodb[graph]==0.1.8.post3->vinagent) (27.0.0)
# Requirement already satisfied: nest-asyncio in /Users/phamdinhkhanh/Documents/Courses/Manus/vinagent/.venv/lib/python3.10/site-packages (from ipykernel==6.29.5->aucodb[graph]==0.1.8.post3->vinagent) (1.6.0)
# Requirement already satisfied: psutil in /Users/phamdinhkhanh/Documents/Courses/Manus/vinagent/.venv/lib/python3.10/site-packages (from ipykernel==6.29.5->aucodb[graph]==0.1.8.post3->vinagent) (7.0.0)
# Requirement already satisfied: comm>=0.1.1 in /Users/phamdinhkhanh/Documents/Courses/Manus/vinagent/.venv/lib/python3.10/site-packages (from ipykernel==6.29.5->aucodb[graph]==0.1.8.post3->vinagent) (0.2.2)
# Requirement already satisfied: traitlets>=5.4.0 in /Users/phamdinhkhanh/Documents/Courses/Manus/vinagent/.venv/lib/python3.10/site-packages (from ipykernel==6.29.5->aucodb[graph]==0.1.8.post3->vinagent) (5.14.3)
# Requirement already satisfied: ipython>=7.23.1 in /Users/phamdinhkhanh/Documents/Courses/Manus/vinagent/.venv/lib/python3.10/site-packages (from ipykernel==6.29.5->aucodb[graph]==0.1.8.post3->vinagent) (8.37.0)
# Requirement already satisfied: jinja2>=2.9.6 in /Users/phamdinhkhanh/Documents/Courses/Manus/vinagent/.venv/lib/python3.10/site-packages (from pyvis==0.3.2->aucodb[graph]==0.1.8.post3->vinagent) (3.1.6)
# Requirement already satisfied: networkx>=1.11 in /Users/phamdinhkhanh/Documents/Courses/Manus/vinagent/.venv/lib/python3.10/site-packages (from pyvis==0.3.2->aucodb[graph]==0.1.8.post3->vinagent) (3.4.2)
# Requirement already satisfied: jsonpickle>=1.4.1 in /Users/phamdinhkhanh/Documents/Courses/Manus/vinagent/.venv/lib/python3.10/site-packages (from pyvis==0.3.2->aucodb[graph]==0.1.8.post3->vinagent) (4.1.1)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/phamdinhkhanh/Documents/Courses/Manus/vinagent/.venv/lib/python3.10/site-packages (from requests~=2.32.0->arxiv==2.1.3->vinagent) (2025.7.14)
# Requirement already satisfied: idna<4,>=2.5 in /Users/phamdinhkhanh/Documents/Courses/Manus/vinagent/.venv/lib/python3.10/site-packages (from requests~=2.32.0->arxiv==2.1.3->vinagent) (3.10)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/phamdinhkhanh/Documents/Courses/Manus/vinagent/.venv/lib/python3.10/site-packages (from requests~=2.32.0->arxiv==2.1.3->vinagent) (3.4.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/phamdinhkhanh/Documents/Courses/Manus/vinagent/.venv/lib/python3.10/site-packages (from requests~=2.32.0->arxiv==2.1.3->vinagent) (2.5.0)
# Requirement already satisfied: propcache>=0.2.0 in /Users/phamdinhkhanh/Documents/Courses/Manus/vinagent/.venv/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.9.1->langchain-together==0.3.0->vinagent) (0.3.2)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /Users/phamdinhkhanh/Documents/Courses/Manus/vinagent/.venv/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.9.1->langchain-together==0.3.0->vinagent) (4.0.3)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/phamdinhkhanh/Documents/Courses/Manus/vinagent/.venv/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.9.1->langchain-together==0.3.0->vinagent) (1.7.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /Users/phamdinhkhanh/Documents/Courses/Manus/vinagent/.venv/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.9.1->langchain-together==0.3.0->vinagent) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /Users/phamdinhkhanh/Documents/Courses/Manus/vinagent/.venv/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.9.1->langchain-together==0.3.0->vinagent) (1.4.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/phamdinhkhanh/Documents/Courses/Manus/vinagent/.venv/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.9.1->langchain-together==0.3.0->vinagent) (6.6.3)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /Users/phamdinhkhanh/Documents/Courses/Manus/vinagent/.venv/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.9.1->langchain-together==0.3.0->vinagent) (1.20.1)
# Requirement already satisfied: attrs>=17.3.0 in /Users/phamdinhkhanh/Documents/Courses/Manus/vinagent/.venv/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.9.1->langchain-together==0.3.0->vinagent) (25.3.0)
# Requirement already satisfied: Mako in /Users/phamdinhkhanh/Documents/Courses/Manus/vinagent/.venv/lib/python3.10/site-packages (from alembic!=1.10.0,<2->mlflow==3.1.0->vinagent) (1.3.10)
# Requirement already satisfied: tomli in /Users/phamdinhkhanh/Documents/Courses/Manus/vinagent/.venv/lib/python3.10/site-packages (from alembic!=1.10.0,<2->mlflow==3.1.0->vinagent) (2.2.1)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /Users/phamdinhkhanh/Documents/Courses/Manus/vinagent/.venv/lib/python3.10/site-packages (from anyio>=4.5->mcp==1.9.0->vinagent) (1.3.0)
# Requirement already satisfied: sniffio>=1.1 in /Users/phamdinhkhanh/Documents/Courses/Manus/vinagent/.venv/lib/python3.10/site-packages (from anyio>=4.5->mcp==1.9.0->vinagent) (1.3.1)
# Requirement already satisfied: soupsieve>1.2 in /Users/phamdinhkhanh/Documents/Courses/Manus/vinagent/.venv/lib/python3.10/site-packages (from beautifulsoup4>=4.11.1->yfinance==0.2.54->vinagent) (2.7)
# Requirement already satisfied: google-auth~=2.0 in /Users/phamdinhkhanh/Documents/Courses/Manus/vinagent/.venv/lib/python3.10/site-packages (from databricks-sdk<1,>=0.20.0->mlflow-skinny==3.1.0->vinagent) (2.40.3)
# Requirement already satisfied: sgmllib3k in /Users/phamdinhkhanh/Documents/Courses/Manus/vinagent/.venv/lib/python3.10/site-packages (from feedparser~=6.0.10->arxiv==2.1.3->vinagent) (1.0.0)
# Requirement already satisfied: itsdangerous>=2.2.0 in /Users/phamdinhkhanh/Documents/Courses/Manus/vinagent/.venv/lib/python3.10/site-packages (from Flask<4->mlflow==3.1.0->vinagent) (2.2.0)
# Requirement already satisfied: werkzeug>=3.1.0 in /Users/phamdinhkhanh/Documents/Courses/Manus/vinagent/.venv/lib/python3.10/site-packages (from Flask<4->mlflow==3.1.0->vinagent) (3.1.3)
# Requirement already satisfied: markupsafe>=2.1.1 in /Users/phamdinhkhanh/Documents/Courses/Manus/vinagent/.venv/lib/python3.10/site-packages (from Flask<4->mlflow==3.1.0->vinagent) (3.0.2)
# Requirement already satisfied: blinker>=1.9.0 in /Users/phamdinhkhanh/Documents/Courses/Manus/vinagent/.venv/lib/python3.10/site-packages (from Flask<4->mlflow==3.1.0->vinagent) (1.9.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /Users/phamdinhkhanh/Documents/Courses/Manus/vinagent/.venv/lib/python3.10/site-packages (from gitpython<4,>=3.1.9->mlflow-skinny==3.1.0->vinagent) (4.0.12)
# Requirement already satisfied: graphql-core<3.3,>=3.1 in /Users/phamdinhkhanh/Documents/Courses/Manus/vinagent/.venv/lib/python3.10/site-packages (from graphene<4->mlflow==3.1.0->vinagent) (3.2.6)
# Requirement already satisfied: graphql-relay<3.3,>=3.1 in /Users/phamdinhkhanh/Documents/Courses/Manus/vinagent/.venv/lib/python3.10/site-packages (from graphene<4->mlflow==3.1.0->vinagent) (3.2.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /Users/phamdinhkhanh/Documents/Courses/Manus/vinagent/.venv/lib/python3.10/site-packages (from groq<1,>=0.29.0->langchain-groq==0.3.6->vinagent) (1.9.0)
# Requirement already satisfied: httpcore==1.* in /Users/phamdinhkhanh/Documents/Courses/Manus/vinagent/.venv/lib/python3.10/site-packages (from httpx>=0.27->mcp==1.9.0->vinagent) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /Users/phamdinhkhanh/Documents/Courses/Manus/vinagent/.venv/lib/python3.10/site-packages (from httpcore==1.*->httpx>=0.27->mcp==1.9.0->vinagent) (0.16.0)
# Requirement already satisfied: zipp>=3.20 in /Users/phamdinhkhanh/Documents/Courses/Manus/vinagent/.venv/lib/python3.10/site-packages (from importlib_metadata!=4.7.0,<9,>=3.7.0->mlflow-skinny==3.1.0->vinagent) (3.23.0)
# Requirement already satisfied: jsonpointer>=1.9 in /Users/phamdinhkhanh/Documents/Courses/Manus/vinagent/.venv/lib/python3.10/site-packages (from jsonpatch<2.0,>=1.33->langchain-core==0.3.68->vinagent) (3.0.0)
# Requirement already satisfied: ormsgpack>=1.10.0 in /Users/phamdinhkhanh/Documents/Courses/Manus/vinagent/.venv/lib/python3.10/site-packages (from langgraph-checkpoint>=2.0.26->langgraph==0.4.7->vinagent) (1.10.0)
# Requirement already satisfied: orjson>=3.10.1 in /Users/phamdinhkhanh/Documents/Courses/Manus/vinagent/.venv/lib/python3.10/site-packages (from langgraph-sdk>=0.1.42->langgraph==0.4.7->vinagent) (3.11.0)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /Users/phamdinhkhanh/Documents/Courses/Manus/vinagent/.venv/lib/python3.10/site-packages (from langsmith>=0.3.45->langchain-core==0.3.68->vinagent) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in /Users/phamdinhkhanh/Documents/Courses/Manus/vinagent/.venv/lib/python3.10/site-packages (from langsmith>=0.3.45->langchain-core==0.3.68->vinagent) (0.23.0)
# Requirement already satisfied: tqdm>4 in /Users/phamdinhkhanh/Documents/Courses/Manus/vinagent/.venv/lib/python3.10/site-packages (from openai<2.0.0,>=1.58.1->langchain-openai==0.3.7->vinagent) (4.67.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in /Users/phamdinhkhanh/Documents/Courses/Manus/vinagent/.venv/lib/python3.10/site-packages (from openai<2.0.0,>=1.58.1->langchain-openai==0.3.7->vinagent) (0.10.0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.56b0 in /Users/phamdinhkhanh/Documents/Courses/Manus/vinagent/.venv/lib/python3.10/site-packages (from opentelemetry-sdk<3,>=1.9.0->mlflow-skinny==3.1.0->vinagent) (0.56b0)
# Requirement already satisfied: typing-inspection>=0.4.0 in /Users/phamdinhkhanh/Documents/Courses/Manus/vinagent/.venv/lib/python3.10/site-packages (from pydantic<3.0,>=2.0->aucodb[graph]==0.1.8.post3->vinagent) (0.4.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/phamdinhkhanh/Documents/Courses/Manus/vinagent/.venv/lib/python3.10/site-packages (from pydantic<3.0,>=2.0->aucodb[graph]==0.1.8.post3->vinagent) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /Users/phamdinhkhanh/Documents/Courses/Manus/vinagent/.venv/lib/python3.10/site-packages (from pydantic<3.0,>=2.0->aucodb[graph]==0.1.8.post3->vinagent) (2.33.2)
# Requirement already satisfied: six>=1.5 in /Users/phamdinhkhanh/Documents/Courses/Manus/vinagent/.venv/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib==3.7.1->vinagent) (1.17.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /Users/phamdinhkhanh/Documents/Courses/Manus/vinagent/.venv/lib/python3.10/site-packages (from scikit-learn<2->mlflow==3.1.0->vinagent) (3.6.0)
# Requirement already satisfied: joblib>=1.2.0 in /Users/phamdinhkhanh/Documents/Courses/Manus/vinagent/.venv/lib/python3.10/site-packages (from scikit-learn<2->mlflow==3.1.0->vinagent) (1.5.1)
# Requirement already satisfied: regex>=2022.1.18 in /Users/phamdinhkhanh/Documents/Courses/Manus/vinagent/.venv/lib/python3.10/site-packages (from tiktoken<1,>=0.7->langchain-openai==0.3.7->vinagent) (2024.11.6)
# Requirement already satisfied: smmap<6,>=3.0.1 in /Users/phamdinhkhanh/Documents/Courses/Manus/vinagent/.venv/lib/python3.10/site-packages (from gitdb<5,>=4.0.1->gitpython<4,>=3.1.9->mlflow-skinny==3.1.0->vinagent) (5.0.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Users/phamdinhkhanh/Documents/Courses/Manus/vinagent/.venv/lib/python3.10/site-packages (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.1.0->vinagent) (4.9.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/phamdinhkhanh/Documents/Courses/Manus/vinagent/.venv/lib/python3.10/site-packages (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.1.0->vinagent) (0.4.2)
# Requirement already satisfied: pexpect>4.3 in /Users/phamdinhkhanh/Documents/Courses/Manus/vinagent/.venv/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel==6.29.5->aucodb[graph]==0.1.8.post3->vinagent) (4.9.0)
# Requirement already satisfied: pygments>=2.4.0 in /Users/phamdinhkhanh/Documents/Courses/Manus/vinagent/.venv/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel==6.29.5->aucodb[graph]==0.1.8.post3->vinagent) (2.19.2)
# Requirement already satisfied: stack_data in /Users/phamdinhkhanh/Documents/Courses/Manus/vinagent/.venv/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel==6.29.5->aucodb[graph]==0.1.8.post3->vinagent) (0.6.3)
# Requirement already satisfied: jedi>=0.16 in /Users/phamdinhkhanh/Documents/Courses/Manus/vinagent/.venv/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel==6.29.5->aucodb[graph]==0.1.8.post3->vinagent) (0.19.2)
# Requirement already satisfied: decorator in /Users/phamdinhkhanh/Documents/Courses/Manus/vinagent/.venv/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel==6.29.5->aucodb[graph]==0.1.8.post3->vinagent) (5.2.1)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /Users/phamdinhkhanh/Documents/Courses/Manus/vinagent/.venv/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel==6.29.5->aucodb[graph]==0.1.8.post3->vinagent) (3.0.51)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /Users/phamdinhkhanh/Documents/Courses/Manus/vinagent/.venv/lib/python3.10/site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel==6.29.5->aucodb[graph]==0.1.8.post3->vinagent) (0.8.4)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/phamdinhkhanh/Documents/Courses/Manus/vinagent/.venv/lib/python3.10/site-packages (from pexpect>4.3->ipython>=7.23.1->ipykernel==6.29.5->aucodb[graph]==0.1.8.post3->vinagent) (0.7.0)
# Requirement already satisfied: wcwidth in /Users/phamdinhkhanh/Documents/Courses/Manus/vinagent/.venv/lib/python3.10/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel==6.29.5->aucodb[graph]==0.1.8.post3->vinagent) (0.2.13)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /Users/phamdinhkhanh/Documents/Courses/Manus/vinagent/.venv/lib/python3.10/site-packages (from pyasn1-modules>=0.2.1->google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.1.0->vinagent) (0.6.1)
# Requirement already satisfied: pure-eval in /Users/phamdinhkhanh/Documents/Courses/Manus/vinagent/.venv/lib/python3.10/site-packages (from stack_data->ipython>=7.23.1->ipykernel==6.29.5->aucodb[graph]==0.1.8.post3->vinagent) (0.2.3)
# Requirement already satisfied: asttokens>=2.1.0 in /Users/phamdinhkhanh/Documents/Courses/Manus/vinagent/.venv/lib/python3.10/site-packages (from stack_data->ipython>=7.23.1->ipykernel==6.29.5->aucodb[graph]==0.1.8.post3->vinagent) (3.0.0)
# Requirement already satisfied: executing>=1.2.0 in /Users/phamdinhkhanh/Documents/Courses/Manus/vinagent/.venv/lib/python3.10/site-packages (from stack_data->ipython>=7.23.1->ipykernel==6.29.5->aucodb[graph]==0.1.8.post3->vinagent) (2.2.0)
# Installing collected packages: PyJWT, vinagent
#   Attempting uninstall: PyJWT
#     Found existing installation: PyJWT 2.11.0
#     Uninstalling PyJWT-2.11.0:
#       Successfully uninstalled PyJWT-2.11.0
# Successfully installed PyJWT-2.10.1 vinagent-0.0.6.post3
#
# [notice] A new release of pip available: 22.3.1 -> 26.0.1
# [notice] To update, run: pip3.10 install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# Write environment variable

# %%
# %%writefile .env
# OPENAI_API_KEY = "Your API Key"
# Out:
# Overwriting .env

# %% [markdown]
# ## Initialize Memory
#
# Vinagent is outstanding with organizing Memory as a Knowledge Graph. We leverage AucoDB features to enhance graph's capabilities of agent. The graph-based features is supported as follows:
#
# - Graph Construction: Builds knowledge graphs from documents using LLMGraphTransformer class from AucoDB, extracting entities (nodes) and relationships with enriched properties such as categories, roles, or timestamps.
#
# - Property Enrichment: Enhances nodes and relationships with contextual attributes derived from the input text, improving graph expressiveness.
#
# - Graph Visualization: Visualizes the constructed graph and exports it as a html file for easy sharing and analysis.
#
# - Neo4j Integration: Stores and manages graphs in a Neo4j database with secure client initialization.
#
# - Flexible Input: Processes unstructured text to create structured graphs, suitable for applications like knowledge management, AI research, and data analysis.
#
#
# Prerequisites
#
# - Neo4j Database: A running Neo4j instance (local or remote).
# - Python Packages: Install required dependencies:

# %%
# %pip install langchain-openai neo4j python-dotenv
# Out:
# Requirement already satisfied: langchain-openai in /Users/phamdinhkhanh/Documents/Courses/Manus/vinagent/.venv/lib/python3.10/site-packages (0.3.7)
# Requirement already satisfied: neo4j in /Users/phamdinhkhanh/Documents/Courses/Manus/vinagent/.venv/lib/python3.10/site-packages (5.28.1)
# Requirement already satisfied: python-dotenv in /Users/phamdinhkhanh/Documents/Courses/Manus/vinagent/.venv/lib/python3.10/site-packages (1.0.0)
# Requirement already satisfied: openai<2.0.0,>=1.58.1 in /Users/phamdinhkhanh/Documents/Courses/Manus/vinagent/.venv/lib/python3.10/site-packages (from langchain-openai) (1.97.0)
# Requirement already satisfied: tiktoken<1,>=0.7 in /Users/phamdinhkhanh/Documents/Courses/Manus/vinagent/.venv/lib/python3.10/site-packages (from langchain-openai) (0.9.0)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.39 in /Users/phamdinhkhanh/Documents/Courses/Manus/vinagent/.venv/lib/python3.10/site-packages (from langchain-openai) (0.3.68)
# Requirement already satisfied: pytz in /Users/phamdinhkhanh/Documents/Courses/Manus/vinagent/.venv/lib/python3.10/site-packages (from neo4j) (2025.2)
# Requirement already satisfied: pydantic>=2.7.4 in /Users/phamdinhkhanh/Documents/Courses/Manus/vinagent/.venv/lib/python3.10/site-packages (from langchain-core<1.0.0,>=0.3.39->langchain-openai) (2.11.7)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /Users/phamdinhkhanh/Documents/Courses/Manus/vinagent/.venv/lib/python3.10/site-packages (from langchain-core<1.0.0,>=0.3.39->langchain-openai) (1.33)
# Requirement already satisfied: PyYAML>=5.3 in /Users/phamdinhkhanh/Documents/Courses/Manus/vinagent/.venv/lib/python3.10/site-packages (from langchain-core<1.0.0,>=0.3.39->langchain-openai) (6.0.2)
# Requirement already satisfied: langsmith>=0.3.45 in /Users/phamdinhkhanh/Documents/Courses/Manus/vinagent/.venv/lib/python3.10/site-packages (from langchain-core<1.0.0,>=0.3.39->langchain-openai) (0.3.45)
# Requirement already satisfied: typing-extensions>=4.7 in /Users/phamdinhkhanh/Documents/Courses/Manus/vinagent/.venv/lib/python3.10/site-packages (from langchain-core<1.0.0,>=0.3.39->langchain-openai) (4.14.1)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /Users/phamdinhkhanh/Documents/Courses/Manus/vinagent/.venv/lib/python3.10/site-packages (from langchain-core<1.0.0,>=0.3.39->langchain-openai) (9.1.2)
# Requirement already satisfied: packaging<25,>=23.2 in /Users/phamdinhkhanh/Documents/Courses/Manus/vinagent/.venv/lib/python3.10/site-packages (from langchain-core<1.0.0,>=0.3.39->langchain-openai) (24.2)
# Requirement already satisfied: jiter<1,>=0.4.0 in /Users/phamdinhkhanh/Documents/Courses/Manus/vinagent/.venv/lib/python3.10/site-packages (from openai<2.0.0,>=1.58.1->langchain-openai) (0.10.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /Users/phamdinhkhanh/Documents/Courses/Manus/vinagent/.venv/lib/python3.10/site-packages (from openai<2.0.0,>=1.58.1->langchain-openai) (4.9.0)
# Requirement already satisfied: tqdm>4 in /Users/phamdinhkhanh/Documents/Courses/Manus/vinagent/.venv/lib/python3.10/site-packages (from openai<2.0.0,>=1.58.1->langchain-openai) (4.67.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /Users/phamdinhkhanh/Documents/Courses/Manus/vinagent/.venv/lib/python3.10/site-packages (from openai<2.0.0,>=1.58.1->langchain-openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /Users/phamdinhkhanh/Documents/Courses/Manus/vinagent/.venv/lib/python3.10/site-packages (from openai<2.0.0,>=1.58.1->langchain-openai) (0.28.1)
# Requirement already satisfied: sniffio in /Users/phamdinhkhanh/Documents/Courses/Manus/vinagent/.venv/lib/python3.10/site-packages (from openai<2.0.0,>=1.58.1->langchain-openai) (1.3.1)
# Requirement already satisfied: requests>=2.26.0 in /Users/phamdinhkhanh/Documents/Courses/Manus/vinagent/.venv/lib/python3.10/site-packages (from tiktoken<1,>=0.7->langchain-openai) (2.32.3)
# Requirement already satisfied: regex>=2022.1.18 in /Users/phamdinhkhanh/Documents/Courses/Manus/vinagent/.venv/lib/python3.10/site-packages (from tiktoken<1,>=0.7->langchain-openai) (2024.11.6)
# Requirement already satisfied: idna>=2.8 in /Users/phamdinhkhanh/Documents/Courses/Manus/vinagent/.venv/lib/python3.10/site-packages (from anyio<5,>=3.5.0->openai<2.0.0,>=1.58.1->langchain-openai) (3.10)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /Users/phamdinhkhanh/Documents/Courses/Manus/vinagent/.venv/lib/python3.10/site-packages (from anyio<5,>=3.5.0->openai<2.0.0,>=1.58.1->langchain-openai) (1.3.0)
# Requirement already satisfied: certifi in /Users/phamdinhkhanh/Documents/Courses/Manus/vinagent/.venv/lib/python3.10/site-packages (from httpx<1,>=0.23.0->openai<2.0.0,>=1.58.1->langchain-openai) (2025.7.14)
# Requirement already satisfied: httpcore==1.* in /Users/phamdinhkhanh/Documents/Courses/Manus/vinagent/.venv/lib/python3.10/site-packages (from httpx<1,>=0.23.0->openai<2.0.0,>=1.58.1->langchain-openai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /Users/phamdinhkhanh/Documents/Courses/Manus/vinagent/.venv/lib/python3.10/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai<2.0.0,>=1.58.1->langchain-openai) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in /Users/phamdinhkhanh/Documents/Courses/Manus/vinagent/.venv/lib/python3.10/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.39->langchain-openai) (3.0.0)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /Users/phamdinhkhanh/Documents/Courses/Manus/vinagent/.venv/lib/python3.10/site-packages (from langsmith>=0.3.45->langchain-core<1.0.0,>=0.3.39->langchain-openai) (1.0.0)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /Users/phamdinhkhanh/Documents/Courses/Manus/vinagent/.venv/lib/python3.10/site-packages (from langsmith>=0.3.45->langchain-core<1.0.0,>=0.3.39->langchain-openai) (3.11.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in /Users/phamdinhkhanh/Documents/Courses/Manus/vinagent/.venv/lib/python3.10/site-packages (from langsmith>=0.3.45->langchain-core<1.0.0,>=0.3.39->langchain-openai) (0.23.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /Users/phamdinhkhanh/Documents/Courses/Manus/vinagent/.venv/lib/python3.10/site-packages (from pydantic>=2.7.4->langchain-core<1.0.0,>=0.3.39->langchain-openai) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /Users/phamdinhkhanh/Documents/Courses/Manus/vinagent/.venv/lib/python3.10/site-packages (from pydantic>=2.7.4->langchain-core<1.0.0,>=0.3.39->langchain-openai) (0.4.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/phamdinhkhanh/Documents/Courses/Manus/vinagent/.venv/lib/python3.10/site-packages (from pydantic>=2.7.4->langchain-core<1.0.0,>=0.3.39->langchain-openai) (0.7.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/phamdinhkhanh/Documents/Courses/Manus/vinagent/.venv/lib/python3.10/site-packages (from requests>=2.26.0->tiktoken<1,>=0.7->langchain-openai) (2.5.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/phamdinhkhanh/Documents/Courses/Manus/vinagent/.venv/lib/python3.10/site-packages (from requests>=2.26.0->tiktoken<1,>=0.7->langchain-openai) (3.4.2)
#
# [notice] A new release of pip available: 22.3.1 -> 26.0.1
# [notice] To update, run: pip3.10 install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
from langchain_openai import ChatOpenAI
from dotenv import load_dotenv, find_dotenv
from vinagent.memory import Memory

load_dotenv(find_dotenv('.env'))

llm = ChatOpenAI(
    model="gpt-4o-mini",   # fast & cheap
    temperature=0.7
)

memory = Memory(
    memory_path="templates/memory.jsonl",
    is_reset_memory=True, # will reset the memory every time the agent is invoked
    is_logging=True
)

# %%
text_input = """Hi, my name is Kan. I was born in Thanh Hoa Province, Vietnam, in 1993.
My motto is: "Make the world better with data and models". That’s why I am working as an AI Solution Architect at FPT Software and as an AI lecturer at DataScienceWorld.Kan.

I began my journey as a gifted student in Mathematics at the High School for Gifted Students, VNU University, where I developed a deep passion for Math and Science since 2009. Later, I completed Bachelor's Degree in Mathematical Economics in 2015 with excellent level. In the meantime, I won a bronze medal at the National Math Olympiad at Calculus.

After graduation, I started my journey by writing AI/Machine Learning blogs with R on RPubs and python on phamdinhkhanh.github.io, where I share my knowledge and explain complex machine learning algorithms in a simple way, along with many practical use cases.
I have been working as an AI Solution Architect at FPT Software since 2024 and at Orient Software since 2022. Previously, I worked at Vingroup as an Senior AI Engineer starting in 2017. I began my career at financial institutions like Techcombank and VNDIRECT in 2015, where I worked for two years as a Data Scientist.

In aspect of education, I designed 6 specialized courses about Deep Learning and Machine Learning that helps to train thoudsands of students essential Machine Learning skills at DataScienceWorld.Kan. Fortunately, I was invited to train many AI/ML program for bigtech companies and universities in Vietnam like Google Cloud - QuanQuanGCP 2024, Viettel - Digital Talent Program 2024, FPT Software - Upskill LLM/GenAI for Engineers 2025, NEU university - Design machine learning system 2025, FTU - Upskill AI Olympiad Team 2025. Since 2024, I have participated in Google GDSC as AI/ML mentors for dedicated AI startups.

In aspect of research, I have conducted extensive research on Reliable AI, Generative AI, and Knowledge Graphs at FPT AI1. Where I have won a paper award on the topic of Generative AI and LLMs at the Nvidia GTC Global Conference 2025.

I am the founder of DataScienceWorld.Kan, an AI learning hub offering useful AI/ML courses such as Deep Learning, Machine Learning Handson with Python, Build Generative AI Applications and MLOps – Machine Learning in Production, designed for anyone pursuing a career as an AI/ML engineer.

In addition, my eBook Machine Learning Algorithms to Practice, published on phamdinhkhanh.github.io/deepai-book, is a widely used resource for students worldwide to study and practice machine learning, featuring intuitive code examples and clear explanations of machine learning theory.
"""

memory.save_short_term_memory(llm, text_input, user_id="Kan")
memory_message = memory.load_memory_by_user(load_type='string', user_id="Kan")
print(memory_message)
# Out:
# 2026-02-13 13:10:02,008 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2026-02-13 13:10:02,017 - INFO - Insert new line: {'head': 'Kan', 'head_type': 'Person', 'relation': 'BORN_IN', 'relation_properties': 'in 1993', 'tail': 'Thanh Hoa Province, Vietnam', 'tail_type': 'Location'}
# 2026-02-13 13:10:02,017 - INFO - Insert new line: {'head': 'Kan', 'head_type': 'Person', 'relation': 'WORKS_FOR', 'relation_properties': 'since 2024', 'tail': 'FPT Software', 'tail_type': 'Company'}
# 2026-02-13 13:10:02,018 - INFO - Insert new line: {'head': 'Kan', 'head_type': 'Person', 'relation': 'WORKS_FOR', 'relation_properties': 'since 2022', 'tail': 'Orient Software', 'tail_type': 'Company'}
# 2026-02-13 13:10:02,018 - INFO - Insert new line: {'head': 'Kan', 'head_type': 'Person', 'relation': 'WORKED_FOR', 'relation_properties': 'starting in 2017', 'tail': 'Vingroup', 'tail_type': 'Company'}
# 2026-02-13 13:10:02,019 - INFO - Insert new line: {'head': 'Kan', 'head_type': 'Person', 'relation': 'WORKED_FOR', 'relation_properties': 'in 2015 for two years', 'tail': 'Techcombank', 'tail_type': 'Company'}
# 2026-02-13 13:10:02,019 - INFO - Insert new line: {'head': 'Kan', 'head_type': 'Person', 'relation': 'WORKED_FOR', 'relation_properties': 'in 2015 for two years', 'tail': 'VNDIRECT', 'tail_type': 'Company'}
# 2026-02-13 13:10:02,019 - INFO - Insert new line: {'head': 'Kan', 'head_type': 'Person', 'relation': 'DESIGNED_COURSE', 'relation_properties': '', 'tail': '6 specialized courses about Deep Learning and Machine Learning', 'tail_type': 'Course'}
# 2026-02-13 13:10:02,020 - INFO - Insert new line: {'head': 'Kan', 'head_type': 'Person', 'relation': 'HAS_AWARD', 'relation_properties': '', 'tail': 'paper award on Generative AI and LLMs', 'tail_type': 'Award'}
# 2026-02-13 13:10:02,020 - INFO - Insert new line: {'head': 'Kan', 'head_type': 'Person', 'relation': 'FOUNDED', 'relation_properties': '', 'tail': 'DataScienceWorld.Kan', 'tail_type': 'Organization'}
# 2026-02-13 13:10:02,021 - INFO - Insert new line: {'head': 'DataScienceWorld.Kan', 'head_type': 'Organization', 'relation': 'OFFERS_COURSE', 'relation_properties': '', 'tail': 'high-standard AI/ML courses such as Deep Learning, Machine Learning Handson with Python, Build Generative AI Applications and MLOps – Machine Learning in Production', 'tail_type': 'Course'}
# 2026-02-13 13:10:02,021 - INFO - Insert new line: {'head': 'Kan', 'head_type': 'Person', 'relation': 'PUBLISHED', 'relation_properties': '', 'tail': 'Machine Learning Algorithms to Practice', 'tail_type': 'Book'}
# 2026-02-13 13:10:02,022 - INFO - Insert new line: {'head': 'Machine Learning Algorithms to Practice', 'head_type': 'Book', 'relation': 'PUBLISHED_ON', 'relation_properties': '', 'tail': 'phamdinhkhanh.github.io/deepai-book', 'tail_type': 'Website'}
# 2026-02-13 13:10:02,023 - INFO - Insert new line: {'head': 'Kan', 'head_type': 'Person', 'relation': 'PARTICIPATED_IN', 'relation_properties': 'since 2024', 'tail': 'Google GDSC', 'tail_type': 'Organization'}
# 2026-02-13 13:10:02,023 - INFO - Insert new line: {'head': 'Kan', 'head_type': 'Person', 'relation': 'MENTORS', 'relation_properties': '', 'tail': 'dedicated AI startups', 'tail_type': 'Startup'}
# 2026-02-13 13:10:02,024 - INFO - Insert new line: {'head': 'Kan', 'head_type': 'Person', 'relation': 'RESEARCH_ON', 'relation_properties': '', 'tail': 'Reliable AI, Generative AI, and Knowledge Graphs', 'tail_type': 'Research_Topic'}
# 2026-02-13 13:10:02,024 - INFO - Insert new line: {'head': 'Google Cloud - QuanQuanGCP 2024', 'head_type': 'Program', 'relation': 'INVITED_FOR', 'relation_properties': '', 'tail': 'Kan', 'tail_type': 'Person'}
# 2026-02-13 13:10:02,025 - INFO - Insert new line: {'head': 'Viettel - Digital Talent Program 2024', 'head_type': 'Program', 'relation': 'INVITED_FOR', 'relation_properties': '', 'tail': 'Kan', 'tail_type': 'Person'}
# 2026-02-13 13:10:02,025 - INFO - Insert new line: {'head': 'FPT Software - Upskill LLM/GenAI for Engineers 2025', 'head_type': 'Program', 'relation': 'INVITED_FOR', 'relation_properties': '', 'tail': 'Kan', 'tail_type': 'Person'}
# 2026-02-13 13:10:02,025 - INFO - Insert new line: {'head': 'NEU university - Design machine learning system 2025', 'head_type': 'Program', 'relation': 'INVITED_FOR', 'relation_properties': '', 'tail': 'Kan', 'tail_type': 'Person'}
# 2026-02-13 13:10:02,026 - INFO - Insert new line: {'head': 'FTU - Upskill AI Olympiad Team 2025', 'head_type': 'Program', 'relation': 'INVITED_FOR', 'relation_properties': '', 'tail': 'Kan', 'tail_type': 'Person'}
# 2026-02-13 13:10:02,028 - INFO - Saved memory!
# Kan -> BORN_IN[in 1993] -> Thanh Hoa Province, Vietnam
# Kan -> WORKS_FOR[since 2024] -> FPT Software
# Kan -> WORKS_FOR[since 2022] -> Orient Software
# Kan -> WORKED_FOR[starting in 2017] -> Vingroup
# Kan -> WORKED_FOR[in 2015 for two years] -> Techcombank
# Kan -> WORKED_FOR[in 2015 for two years] -> VNDIRECT
# Kan -> DESIGNED_COURSE -> 6 specialized courses about Deep Learning and Machine Learning
# Kan -> HAS_AWARD -> paper award on Generative AI and LLMs
# Kan -> FOUNDED -> DataScienceWorld.Kan
# DataScienceWorld.Kan -> OFFERS_COURSE -> high-standard AI/ML courses such as Deep Learning, Machine Learning Handson with Python, Build Generative AI Applications and MLOps – Machine Learning in Production
# Kan -> PUBLISHED -> Machine Learning Algorithms to Practice
# Machine Learning Algorithms to Practice -> PUBLISHED_ON -> phamdinhkhanh.github.io/deepai-book
# Kan -> PARTICIPATED_IN[since 2024] -> Google GDSC
# Kan -> MENTORS -> dedicated AI startups
# Kan -> RESEARCH_ON -> Reliable AI, Generative AI, and Knowledge Graphs
# Google Cloud - QuanQuanGCP 2024 -> INVITED_FOR -> Kan
# Viettel - Digital Talent Program 2024 -> INVITED_FOR -> Kan
# FPT Software - Upskill LLM/GenAI for Engineers 2025 -> INVITED_FOR -> Kan
# NEU university - Design machine learning system 2025 -> INVITED_FOR -> Kan
# FTU - Upskill AI Olympiad Team 2025 -> INVITED_FOR -> Kan

# %% [markdown]
# ## Load memory by user_id
#
# Memory is organized by `user_id` to segment each user’s data within the long-term memory. Before starting a conversation, the agent can access the memory associated with the given `user_id`, which helps prevent confusion between users the agent has previously interacted with and toward on a more personalized experience. For instance, if the agent has a conversation with Mr. Kan, it can recall all that information in future sessions by referencing `user_id='Kan'`

# %%
message_user = memory.load_memory_by_user(load_type='list', user_id="Kan")

# %%
message_user

# %% [markdown]
# ## Visualize on Neo4j
#
# You can explore the knowledge graph on-premise using the Neo4j dashboard at `http://localhost:7474/browser/`. This allows you to intuitively understand the nodes and relationships within your data.
#
# To enable this visualization, the `AucoDBNeo4jClient`, a client instance from the `AucoDB` library, supports ingesting graph memory directly into a `Neo4j` database. Once the data is ingested, you can use `Cypher` queries to retrieve nodes and edges for inspection or further analysis.
#
# **Note:**
# Authentication: Access to the Neo4j dashboard requires login using the same `username/password` credentials configured in your Docker environment (e.g., via the NEO4J_AUTH variable).
#
# If you prefer not to use the `Neo4j` web interface, the `AucoDBNeo4jClient` also provides a convenient method to export the entire graph to an HTML file, which is `client.visualize_graph(output_path="my_graph.html")`.
#
# This method generates a standalone HTML file containing an interactive graph visualization, ideal for embedding in reports or sharing with others without requiring Neo4j access.

# %% [markdown]
# ### Start Neo4j service
#
# Neo4j database can be install as a docker service. We need to create a `docker-compose.yml` file on local and start `Neo4j` database as follows:

# %%
# %%writefile docker-compose.yml
# version: '3.8'
#
# services:
#   neo4j:
#     image: neo4j:latest
#     container_name: neo4j
#     ports:
#       - "7474:7474"
#       - "7687:7687"
#     environment:
#       - NEO4J_AUTH=neo4j/abc@12345

# %% [markdown]
# Start `neo4j` service by command:

# %%
docker-compose up

# %% [markdown]
# ### Export Knowledge Graph

# %% [markdown]
# Install dependency `AucoDB` library to ingest knowledge graph to `Neo4j` database and and export graph to html file.

# %%
# %pip install -U aucodb
# Out:
# Requirement already satisfied: aucodb in /Users/phamdinhkhanh/Documents/Courses/Manus/vinagent/.venv/lib/python3.10/site-packages (0.1.8.post3)
# Requirement already satisfied: requests==2.32.3 in /Users/phamdinhkhanh/Documents/Courses/Manus/vinagent/.venv/lib/python3.10/site-packages (from aucodb) (2.32.3)
# Requirement already satisfied: fastapi<0.116.0,>=0.115.0 in /Users/phamdinhkhanh/Documents/Courses/Manus/vinagent/.venv/lib/python3.10/site-packages (from aucodb) (0.115.14)
# Requirement already satisfied: aiofiles==24.1.0 in /Users/phamdinhkhanh/Documents/Courses/Manus/vinagent/.venv/lib/python3.10/site-packages (from aucodb) (24.1.0)
# Requirement already satisfied: uvicorn>=0.22.0 in /Users/phamdinhkhanh/Documents/Courses/Manus/vinagent/.venv/lib/python3.10/site-packages (from aucodb) (0.35.0)
# Requirement already satisfied: pydantic<3.0,>=2.0 in /Users/phamdinhkhanh/Documents/Courses/Manus/vinagent/.venv/lib/python3.10/site-packages (from aucodb) (2.11.7)
# Requirement already satisfied: ipykernel==6.29.5 in /Users/phamdinhkhanh/Documents/Courses/Manus/vinagent/.venv/lib/python3.10/site-packages (from aucodb) (6.29.5)
# Requirement already satisfied: appnope in /Users/phamdinhkhanh/Documents/Courses/Manus/vinagent/.venv/lib/python3.10/site-packages (from ipykernel==6.29.5->aucodb) (0.1.4)
# Requirement already satisfied: traitlets>=5.4.0 in /Users/phamdinhkhanh/Documents/Courses/Manus/vinagent/.venv/lib/python3.10/site-packages (from ipykernel==6.29.5->aucodb) (5.14.3)
# Requirement already satisfied: packaging in /Users/phamdinhkhanh/Documents/Courses/Manus/vinagent/.venv/lib/python3.10/site-packages (from ipykernel==6.29.5->aucodb) (24.2)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /Users/phamdinhkhanh/Documents/Courses/Manus/vinagent/.venv/lib/python3.10/site-packages (from ipykernel==6.29.5->aucodb) (5.8.1)
# Requirement already satisfied: psutil in /Users/phamdinhkhanh/Documents/Courses/Manus/vinagent/.venv/lib/python3.10/site-packages (from ipykernel==6.29.5->aucodb) (7.0.0)
# Requirement already satisfied: tornado>=6.1 in /Users/phamdinhkhanh/Documents/Courses/Manus/vinagent/.venv/lib/python3.10/site-packages (from ipykernel==6.29.5->aucodb) (6.5.1)
# Requirement already satisfied: debugpy>=1.6.5 in /Users/phamdinhkhanh/Documents/Courses/Manus/vinagent/.venv/lib/python3.10/site-packages (from ipykernel==6.29.5->aucodb) (1.8.15)
# Requirement already satisfied: matplotlib-inline>=0.1 in /Users/phamdinhkhanh/Documents/Courses/Manus/vinagent/.venv/lib/python3.10/site-packages (from ipykernel==6.29.5->aucodb) (0.1.7)
# Requirement already satisfied: comm>=0.1.1 in /Users/phamdinhkhanh/Documents/Courses/Manus/vinagent/.venv/lib/python3.10/site-packages (from ipykernel==6.29.5->aucodb) (0.2.2)
# Requirement already satisfied: pyzmq>=24 in /Users/phamdinhkhanh/Documents/Courses/Manus/vinagent/.venv/lib/python3.10/site-packages (from ipykernel==6.29.5->aucodb) (27.0.0)
# Requirement already satisfied: nest-asyncio in /Users/phamdinhkhanh/Documents/Courses/Manus/vinagent/.venv/lib/python3.10/site-packages (from ipykernel==6.29.5->aucodb) (1.6.0)
# Requirement already satisfied: ipython>=7.23.1 in /Users/phamdinhkhanh/Documents/Courses/Manus/vinagent/.venv/lib/python3.10/site-packages (from ipykernel==6.29.5->aucodb) (8.37.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in /Users/phamdinhkhanh/Documents/Courses/Manus/vinagent/.venv/lib/python3.10/site-packages (from ipykernel==6.29.5->aucodb) (8.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/phamdinhkhanh/Documents/Courses/Manus/vinagent/.venv/lib/python3.10/site-packages (from requests==2.32.3->aucodb) (2025.7.14)
# Requirement already satisfied: idna<4,>=2.5 in /Users/phamdinhkhanh/Documents/Courses/Manus/vinagent/.venv/lib/python3.10/site-packages (from requests==2.32.3->aucodb) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/phamdinhkhanh/Documents/Courses/Manus/vinagent/.venv/lib/python3.10/site-packages (from requests==2.32.3->aucodb) (2.5.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/phamdinhkhanh/Documents/Courses/Manus/vinagent/.venv/lib/python3.10/site-packages (from requests==2.32.3->aucodb) (3.4.2)
# Requirement already satisfied: starlette<0.47.0,>=0.40.0 in /Users/phamdinhkhanh/Documents/Courses/Manus/vinagent/.venv/lib/python3.10/site-packages (from fastapi<0.116.0,>=0.115.0->aucodb) (0.46.2)
# Requirement already satisfied: typing-extensions>=4.8.0 in /Users/phamdinhkhanh/Documents/Courses/Manus/vinagent/.venv/lib/python3.10/site-packages (from fastapi<0.116.0,>=0.115.0->aucodb) (4.14.1)
# Requirement already satisfied: pydantic-core==2.33.2 in /Users/phamdinhkhanh/Documents/Courses/Manus/vinagent/.venv/lib/python3.10/site-packages (from pydantic<3.0,>=2.0->aucodb) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /Users/phamdinhkhanh/Documents/Courses/Manus/vinagent/.venv/lib/python3.10/site-packages (from pydantic<3.0,>=2.0->aucodb) (0.4.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/phamdinhkhanh/Documents/Courses/Manus/vinagent/.venv/lib/python3.10/site-packages (from pydantic<3.0,>=2.0->aucodb) (0.7.0)
# Requirement already satisfied: h11>=0.8 in /Users/phamdinhkhanh/Documents/Courses/Manus/vinagent/.venv/lib/python3.10/site-packages (from uvicorn>=0.22.0->aucodb) (0.16.0)
# Requirement already satisfied: click>=7.0 in /Users/phamdinhkhanh/Documents/Courses/Manus/vinagent/.venv/lib/python3.10/site-packages (from uvicorn>=0.22.0->aucodb) (8.2.1)
# Requirement already satisfied: jedi>=0.16 in /Users/phamdinhkhanh/Documents/Courses/Manus/vinagent/.venv/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel==6.29.5->aucodb) (0.19.2)
# Requirement already satisfied: exceptiongroup in /Users/phamdinhkhanh/Documents/Courses/Manus/vinagent/.venv/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel==6.29.5->aucodb) (1.3.0)
# Requirement already satisfied: pygments>=2.4.0 in /Users/phamdinhkhanh/Documents/Courses/Manus/vinagent/.venv/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel==6.29.5->aucodb) (2.19.2)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /Users/phamdinhkhanh/Documents/Courses/Manus/vinagent/.venv/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel==6.29.5->aucodb) (3.0.51)
# Requirement already satisfied: decorator in /Users/phamdinhkhanh/Documents/Courses/Manus/vinagent/.venv/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel==6.29.5->aucodb) (5.2.1)
# Requirement already satisfied: stack_data in /Users/phamdinhkhanh/Documents/Courses/Manus/vinagent/.venv/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel==6.29.5->aucodb) (0.6.3)
# Requirement already satisfied: pexpect>4.3 in /Users/phamdinhkhanh/Documents/Courses/Manus/vinagent/.venv/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel==6.29.5->aucodb) (4.9.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/phamdinhkhanh/Documents/Courses/Manus/vinagent/.venv/lib/python3.10/site-packages (from jupyter-client>=6.1.12->ipykernel==6.29.5->aucodb) (2.9.0.post0)
# Requirement already satisfied: platformdirs>=2.5 in /Users/phamdinhkhanh/Documents/Courses/Manus/vinagent/.venv/lib/python3.10/site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel==6.29.5->aucodb) (4.3.8)
# Requirement already satisfied: anyio<5,>=3.6.2 in /Users/phamdinhkhanh/Documents/Courses/Manus/vinagent/.venv/lib/python3.10/site-packages (from starlette<0.47.0,>=0.40.0->fastapi<0.116.0,>=0.115.0->aucodb) (4.9.0)
# Requirement already satisfied: sniffio>=1.1 in /Users/phamdinhkhanh/Documents/Courses/Manus/vinagent/.venv/lib/python3.10/site-packages (from anyio<5,>=3.6.2->starlette<0.47.0,>=0.40.0->fastapi<0.116.0,>=0.115.0->aucodb) (1.3.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /Users/phamdinhkhanh/Documents/Courses/Manus/vinagent/.venv/lib/python3.10/site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel==6.29.5->aucodb) (0.8.4)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/phamdinhkhanh/Documents/Courses/Manus/vinagent/.venv/lib/python3.10/site-packages (from pexpect>4.3->ipython>=7.23.1->ipykernel==6.29.5->aucodb) (0.7.0)
# Requirement already satisfied: wcwidth in /Users/phamdinhkhanh/Documents/Courses/Manus/vinagent/.venv/lib/python3.10/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel==6.29.5->aucodb) (0.2.13)
# Requirement already satisfied: six>=1.5 in /Users/phamdinhkhanh/Documents/Courses/Manus/vinagent/.venv/lib/python3.10/site-packages (from python-dateutil>=2.8.2->jupyter-client>=6.1.12->ipykernel==6.29.5->aucodb) (1.17.0)
# Requirement already satisfied: asttokens>=2.1.0 in /Users/phamdinhkhanh/Documents/Courses/Manus/vinagent/.venv/lib/python3.10/site-packages (from stack_data->ipython>=7.23.1->ipykernel==6.29.5->aucodb) (3.0.0)
# Requirement already satisfied: executing>=1.2.0 in /Users/phamdinhkhanh/Documents/Courses/Manus/vinagent/.venv/lib/python3.10/site-packages (from stack_data->ipython>=7.23.1->ipykernel==6.29.5->aucodb) (2.2.0)
# Requirement already satisfied: pure-eval in /Users/phamdinhkhanh/Documents/Courses/Manus/vinagent/.venv/lib/python3.10/site-packages (from stack_data->ipython>=7.23.1->ipykernel==6.29.5->aucodb) (0.2.3)
#
# [notice] A new release of pip available: 22.3.1 -> 26.0.1
# [notice] To update, run: pip3.10 install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# Initialze client instance

# %%
from langchain_together.chat_models import ChatTogether
from aucodb.graph.neo4j_client import AucoDBNeo4jClient
from aucodb.graph import LLMGraphTransformer
from dotenv import load_dotenv

# Step 1: Initialize AucoDBNeo4jClient
# Method 1: dirrectly passing arguments, but not ensure security
NEO4J_URI = "bolt://localhost:7687"  # Update with your Neo4j URI
NEO4J_USER = "neo4j"  # Update with your Neo4j username
NEO4J_PASSWORD = "abc@12345"  # Update with your Neo4j password

client = AucoDBNeo4jClient(uri = NEO4J_URI, user = NEO4J_USER, password = NEO4J_PASSWORD)

# %%
# Step 2: Save user memory into jsonline
import json

with open("user_memory.jsonl", "w") as f:
    for item in message_user:
        f.write(json.dumps(item) + "\n")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 5
#       2 import json
#       4 with open("user_memory.jsonl", "w") as f:
# ----> 5     for item in message_user:
#       6         f.write(json.dumps(item) + "\n")
#
# NameError: name 'message_user' is not defined

# %%
# Step 3: Load user_memory.jsonl into Neo4j.
client.load_json_to_neo4j(
    json_file='user_memory.jsonl',
    is_reset_db=False
)
# Out:
# 2026-02-13 13:38:27,960 - INFO - Inserted 20 items into Neo4j
# 2026-02-13 13:38:27,962 - INFO - Graph creation completed. Inserted 20 valid items

# %%
# Step 4: Export graph into my_graph.html file.
client.visualize_graph(output_file="my_graph.html", show_in_browser=True)
# Out:
# 2026-02-13 13:38:28,695 - INFO - Graph visualization saved to my_graph.html

# %% [markdown]
# ## Agent with memory
#
# This feature allows to adhere `Memory` for each `Agent`. This is useful when you want to keep track of the user's behavior and conceptualize knowledge as a graph. As a result, it helps agent become more intelligent and capable of understanding personality and responding to user queries with greater accuracy.
#
# We structure our memory as a dictionary, where each key represents a user identifier. This memory is then injected into the Agent during initialization by setting `memory_path="your_memory_path.jsonl"` as a long-term memory.
#
# Asking agent with user_id = 'Kan'

# %%
# !cat templates/memory.jsonl
# Out:
# {
#     "Kan": [
#         {
#             "head": "Kan",
#             "head_type": "Person",
#             "relation": "BORN_IN",
#             "relation_properties": "in 1993",
#             "tail": "Thanh Hoa Province, Vietnam",
#             "tail_type": "Location"
#         },
#         {
#             "head": "Kan",
#             "head_type": "Person",
#             "relation": "WORKS_FOR",
#             "relation_properties": "as an AI Solution Architect",
#             "tail": "FPT Software",
#             "tail_type": "Company"
#         },
#         {
#             "head": "Kan",
#             "head_type": "Person",
#             "relation": "WORKS_FOR",
#             "relation_properties": "as an AI lecturer",
#             "tail": "NEU",
#             "tail_type": "University"
#         },
#         {
#             "head": "Kan",
#             "head_type": "Person",
#             "relation": "HAS_AWARD",
#             "relation_properties": "first student from the Math Department",
#             "tail": "bronze medal at the National Math Olympiad",
#             "tail_type": "Award"
#         },
#         {
#             "head": "Kan",
#             "head_type": "Person",
#             "relation": "EARNED_DEGREE",
#             "relation_properties": "in 2015",
#             "tail": "Excellent Bachelor's Degree in Applied Mathematical Economics",
#             "tail_type": "Degree"
#         },
#         {
#             "head": "Kan",
#             "head_type": "Person",
#             "relation": "WORKS_FOR",
#             "relation_properties": "since 2024",
#             "tail": "FPT Software",
#             "tail_type": "Company"
#         },
#         {
#             "head": "Kan",
#             "head_type": "Person",
#             "relation": "TEACHES_AT",
#             "relation_properties": "since 2025",
#             "tail": "NEU university",
#             "tail_type": "University"
#         },
#         {
#             "head": "Kan",
#             "head_type": "Person",
#             "relation": "CONDUCTS_RESEARCH_ON",
#             "relation_properties": "",
#             "tail": "Reliable AI, Generative AI, Knowledge Graphs",
#             "tail_type": "Research_Topics"
#         },
#         {
#             "head": "Kan",
#             "head_type": "Person",
#             "relation": "HAS_AWARD",
#             "relation_properties": "at the Nvidia GTC Global Conference 2025",
#             "tail": "paper award on the topic of Generative AI and LLMs",
#             "tail_type": "Award"
#         },
#         {
#             "head": "Kan",
#             "head_type": "Person",
#             "relation": "FOUNDED",
#             "relation_properties": "",
#             "tail": "DataScienceWorld.Kan",
#             "tail_type": "Organization"
#         },
#         {
#             "head": "Kan",
#             "head_type": "Person",
#             "relation": "PARTICIPATES_IN",
#             "relation_properties": "since 2024",
#             "tail": "Google GDSC",
#             "tail_type": "Event"
#         },
#         {
#             "head": "Kan",
#             "head_type": "Person",
#             "relation": "PARTICIPATES_IN",
#             "relation_properties": "since 2024",
#             "tail": "Google I/O",
#             "tail_type": "Event"
#         }
#     ]
# }

# %% [markdown]
# Asking agent with user_id = 'Kan'

# %%
import os
import sys
from langchain_together import ChatTogether 
from vinagent.agent import Agent
from vinagent.memory.memory import Memory
from pathlib import Path
from dotenv import load_dotenv

load_dotenv()

llm = ChatTogether(
    model="meta-llama/Llama-3.3-70B-Instruct-Turbo-Free"
)

# Step 1: Create Agent with tools
agent = Agent(
    llm = llm,
    description="You are my close friend",
    skills=[
        "You can remember all memory related to us",
        "You can remind the memory to answer questions",
        "You can remember the history of our relationship"
    ],
    memory_path='templates/memory.jsonl',
    is_reset_memory=False # If True, reset memory each time re-initialize agent, else use existing memory
)

# Step 2: invoke the agent
message = agent.invoke("What is your Motto?", user_id="Kan")
message.content

# %% [markdown]
# Each message in the conversation is considered as a short-term memory. You can save them to long-term memory under the Graph form by setting `is_save_memory=True`.

# %%
message = agent.invoke("Hi, I'm Kan, who is a leader of Vinagent project", user_id="Kan", is_save_memory=True)
# Out:
# INFO:vinagent.agent.agent:I'am chatting with Kan
# INFO:httpx:HTTP Request: POST https://api.together.xyz/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:root:Saved to memory the query: Hi, I'm Kan, who is a leader of Vinagent project
# INFO:httpx:HTTP Request: POST https://api.together.xyz/v1/chat/completions "HTTP/1.1 200 OK"

# %%
message
# Out:
# AIMessage(content="Hi Kan, it's great to hear that you're the leader of the Vinagent project. How's the project going so far?", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 28, 'prompt_tokens': 502, 'total_tokens': 530, 'completion_tokens_details': None, 'prompt_tokens_details': None, 'cached_tokens': 0}, 'model_name': 'meta-llama/Llama-3.3-70B-Instruct-Turbo-Free', 'system_fingerprint': None, 'finish_reason': 'stop', 'logprobs': None}, id='run-1866159f-b163-47d1-abdd-437e1b38b316-0', usage_metadata={'input_tokens': 502, 'output_tokens': 28, 'total_tokens': 530, 'input_token_details': {}, 'output_token_details': {}})

# %%
# !cat templates/memory.jsonl
# Out:
# {
#     "Kan": [
#         {
#             "head": "Kan",
#             "head_type": "Person",
#             "relation": "BORN_IN",
#             "relation_properties": "in 1993",
#             "tail": "Thanh Hoa Province, Vietnam",
#             "tail_type": "Location"
#         },
#         {
#             "head": "Kan",
#             "head_type": "Person",
#             "relation": "WORKS_FOR",
#             "relation_properties": "since 2021",
#             "tail": "FPT Software",
#             "tail_type": "Company"
#         },
#         {
#             "head": "Kan",
#             "head_type": "Person",
#             "relation": "WORKS_FOR",
#             "relation_properties": "since 2022",
#             "tail": "NEU",
#             "tail_type": "University"
#         },
#         {
#             "head": "Kan",
#             "head_type": "Person",
#             "relation": "STUDIED_AT",
#             "relation_properties": "",
#             "tail": "High School for Gifted Students, VNU University",
#             "tail_type": "School"
#         },
#         {
#             "head": "Kan",
#             "head_type": "Person",
#             "relation": "STUDIED_AT",
#             "relation_properties": "graduated in 2015",
#             "tail": "NEU University",
#             "tail_type": "University"
#         },
#         {
#             "head": "Kan",
#             "head_type": "Person",
#             "relation": "RESEARCHED_AT",
#             "relation_properties": "",
#             "tail": "FPT AIC",
#             "tail_type": "Institution"
#         },
#         {
#             "head": "Kan",
#             "head_type": "Person",
#             "relation": "RECEIVED_AWARD",
#             "relation_properties": "in 2025",
#             "tail": "Nvidia GTC Global Conference",
#             "tail_type": "Conference"
#         },
#         {
#             "head": "Kan",
#             "head_type": "Person",
#             "relation": "FOUNDED",
#             "relation_properties": "",
#             "tail": "DataScienceWorld.Kan",
#             "tail_type": "Organization"
#         },
#         {
#             "head": "Kan",
#             "head_type": "Person",
#             "relation": "PARTICIPATED_IN",
#             "relation_properties": "since 2024",
#             "tail": "Google GDSC",
#             "tail_type": "Event"
#         },
#         {
#             "head": "Kan",
#             "head_type": "Person",
#             "relation": "PARTICIPATED_IN",
#             "relation_properties": "since 2024",
#             "tail": "Google I/O",
#             "tail_type": "Event"
#         },
#         {
#             "head": "Kan",
#             "head_type": "Person",
#             "relation": "HAS_MOTTO",
#             "relation_properties": "",
#             "tail": "Make the world better with data and models",
#             "tail_type": "Motto"
#         },
#         {
#             "head": "Kan",
#             "head_type": "Person",
#             "relation": "LEADS",
#             "relation_properties": "",
#             "tail": "Vinagent project",
#             "tail_type": "Project"
#         }
#     ]
# }
